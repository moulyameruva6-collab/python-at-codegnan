# %%
class Mobile:
    company = "Iphone"  #class attribute 
    def __init__(self , model , ram , rom , price):
        self.model = model   # with in self word that are instance attribute
        self.ram = ram
        self.rom = rom
        self.price = price
    def about_phone(self):
        return f"The {self.model}have{self.ram}GB RAM and {self.rom}GB ROM"
    def dispay():
        return "This is samsung comapany display"
     # class creation
    @classmethod
    def  update_company(cls,new_name):
       cls.company = new_name
       return "comapny name updated"
     # static menthod
    @staticmethod
    def charger_provide(cable = False):
        return "adpter + cable" if cable else "only adpter"

#object creation:
iphone16 = Mobile("iphone 16",16 , 256 , 125000)
iphone17 = Mobile("iphone 17",8 , 256 , 120000)
print(iphone16.about_phone())
print(iphone16.update_company("Iphone Pro"))
print(iphone17.company)
# Out:
# The iphone 16have16GB RAM and 256GB ROM
# comapny name updated
# Iphone Pro

# %%
class Mobile:
    company = "Iphone"  #class attribute 
    def __init__(self , model , ram , rom , price):
        self.model = model   # with in self word that are instance attribute
        self.ram = ram
        self.rom = rom
        self.price = price


    def about_phone(self):
        return f"The {self.model}have{self.ram}GB RAM and {self.rom}GB ROM"
    def dispay():
        return "This is samsung company display"
     #class creation   
    @classmethod
    def  update_company(cls,new_name):
        cls.company = new_name
        cls.company = "company name updated"
     # static menthod
    @staticmethod
    def charger_provide(cable = False):
        return "adpter + cable" if cable else "only adpter"

#object creation:
iphone16 = Mobile("iphone 16",16 , 256 , 125000)
iphone17 = Mobile("iphone 17",8 , 256 , 120000)
print(iphone16.about_phone())
print(Mobile.update_company("Iphone Pro"))
print(Mobile.charger_provide())
print(Mobile.company)
# Out:
# The iphone 16have16GB RAM and 256GB ROM
# None
# only adpter
# company name updated

# %%
class Account:
    def __init__(self,name,balance,password):
        self.name=name
        self.balance=balance
        self.password=password
    
    def withdraw(self,amount):
        if self.balance >= amount:
            self.balance <= amount
        return f"{amount} withdrawal successfully"
   
    def deposite(self,amount):
        self.balance += amount
        return f"{amount} Deposite successfully and current balance is {self.balance}"
user = Account("moulya",3000,"mouli@12")
print(user.deposite(1000))
user.balance=100000
print(user.withdraw(5000))
# Out:
# 1000 Deposite successfully and current balance is 4000
# 5000 withdrawal successfully
