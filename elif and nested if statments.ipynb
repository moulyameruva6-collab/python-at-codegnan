# %% [markdown]
# marks=int(input())
# if marks>=90:
#     print("A grade")
# if marks>=80:
#     print("B grade")
# if marks>=65:
#     print("C grade")
# if marks>=35 or marks<50:
#     print("D grade")
# else:
#     print("Failed")

# %%
marks=int(input())
if marks<=90:
    print("A grade")
if marks<=80:
    print("B grade")
if marks<=65:
    print("C grade")
if marks<=50:
    print("D grade")
else:
    print("Failed")
# Out:
#  50
# A grade
# B grade
# C grade
# D grade

# %%
marks=int(input())
if marks<=90:
    print("A grade")
if marks<=80:
    print("B grade")
if marks<=65:
    print("C grade")
if marks<=50:
    print("D grade")
else:
    print("Failed")
# Out:
#  95
# Failed

# %%
marks=int(input())
if marks>=90:
    print("A grade")
if marks>=80:
        print("B grade")
if marks>=65:
       print("C grade")
if marks>=35 or marks<50:
    print("D grade") 
else: 
    print("Failed")
# Out:
#  92
# A grade
# B grade
# C grade
# D grade

# %%
num=int(input())
if num % 3 ==0:
    print("Fizz")
elif num % 5 ==0:   
    print("Buzz")
else:
    print("Number")
# Out:
#  15
# Fizz

# %%
num=int(input())
if num % 3 ==0:
    print("Fizz")
if num % 5 ==0:   
    print("Buzz")
else:
    print(num)
# Out:
#  11
# 11

# %%
num=int(input())
if num % 3 ==0:
    print("Fizz")
if num % 5 ==0:   
    print("Buzz")
else:
    print(num)
# Out:
#  30
# Fizz
# Buzz

# %%
num=int(input())
if num % 2 ==0:
    print("even")
if num % 2 ==1:
    print("odd")
# Out:
#  13
# odd

# %%
num=int(input())
if num % 2 ==0:
    print("even")
if num % 2 ==1:
    print("odd")
# Out:
#  42
# even

# %%
num=int(input())
if num % 3 ==0:
    print("Fizz")
elif num % 5 ==0:   
    print("Buzz")
elif num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")
else:
    print(num)
# Out:
#  25
# Buzz

# %%
#
num=int(input())
if num % 3 ==0:
    print("Fizz")
elif num % 5 ==0:   
    print("Buzz")
elif num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")
else:
    print(num)
# Out:
#  15
# Fizz

# %%
#+ve,-ve,zero
num=int(input())
if num >= 0:
    print(f"{num} is positive")
if num <=0:
    print(f"{num} is negative")
else:
    print("Zero")
# Out:
#  22
# 22 is positive
# Zero

# %%
#+ve,-ve,zero
num=int(input())
if num > 0:
    print(f"{num} is positive")
if num <0:
    print(f"{num} is negative")
else :
    print(f"{num} is Zero")
# Out:
#  0
# 0 is Zero

# %%
#+ve,-ve,zero
num=int(input())
if num > 0:
    print("positive")
if num <0:
    print("negative")
else:
    print("Zero")
# Out:
#  22
# positive
# Zero

# %%
num=int(input())
if num >=0 and num % 2 == 0:
    print(f"{num} is even +ve")
elif num >= 0 and num % 2 == 1:
    print(f"{num} is odd +ve")
elif num < 0 and num % 2 ==0:
    print(f"{num} is -ve even")
else:
    print(f"{num} is -ve odd")
# Out:
#  45
# 45 is odd +ve

# %%
num=int(input())
if num >=0 and num % 2 == 0:
    print(f"{num} is even +ve")
elif num >= 0:
    print(f"{num} is odd +ve")
elif num < 0 and num % 2 ==0:
    print(f"{num} is -ve even")
else:
    print(f"{num} is -ve odd")
# Out:
#  -23
# -23 is -ve odd

# %%
num=int(input())
if num > 0 and num % 2 == 0:
    print(f"{num} is even +ve")
elif num > 0:
    print(f"{num} is odd +ve")
elif num < 0 and num % 2 ==0:
    print(f"{num} is -ve even")
elif num < 0:
    print(f"{num} is -ve odd")
else:
    print("Zero")
# Out:
#  0
# Zero

# %%
# find the smaller number among the three numbers:
a=int(input())
b=int(input())
c=int(input())
if a <= b and a <= c:
    print("a is smallest number")
elif b >= a and b >= c:
    print("b is smallest number")
elif c <= a and c <= b:
    print("c is smallest number")
else:
    print("among the smallest number")
# Out:
#  231
#  100
#  346
# among the smallest number

# %%
# find the smaller number among the three numbers:
a=int(input())
b=int(input())
c=int(input())
if a <= b and a <= c:
    print("a is smallest number")
elif b >= a and b >= c:
    print("b is smallest number")
elif c <= a and c <= b:
    print("c is smallest number")
else:
    print("among is smallest number")
# Out:
#  100
#  234
#  654
# a is smallest number

# %%
#+ve,-ve,zero in even and odd:
num=int(input())
if num > 0 :
    if num % 2 == 0:
        print(f"{num} is even +ve")
    else:
        print(f"{num} is odd +ve")
else:
    if num % 2 ==0:
        print(f"{num} is -ve even")
    else:
        print(f"{num} is -ve odd")
# Out:
#  23
# 23 is odd +ve

# %%
# greatest of three numbers:
a=int(input())
b=int(input())
c=int(input())
if a<=b and a<=c:
    print("a is greatest number")
