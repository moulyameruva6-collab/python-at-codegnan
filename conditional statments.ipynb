# %%
###Conditional Statments:
#if else
num=int(input())
if num>=0 :
        print("+ve")
else:
        print("-ve")
# Out:
#  13
# +ve

# %%
num=int(input())
if num % 3:
     print("divisible by 3")
else:  
     print("not divisible by 3")
# Out:
#  26
# divisible by 3

# %%
num=int(input())
if num % 3 and 5:
    print("divisible by 3")
else:
    print("divisible by 5")
# Out:
#  30
# divisible by 5

# %%
#divisible by 3 and 5:
num=int(input())
if num % 3 == 0 and num % 5 == 0:
    print(f"{num} divisible with 3 and 5")
else:
    print(f"{num} divisible with 3 and 5")
# Out:
#  13
# 13 divisible with 3 and 5

# %%
## perfect square:
val=num**0.5
if val==int(val):
    print("perfect square")
else:
    print("not perfect square")
# Out:
# not perfect square

# %%
## perfect square:
val=num**0.5
if val==int(val):
    print(f"{num} perfect square")
else:
    print(f"{num} not perfect square")
# Out:
# 13 not perfect square

# %%
## perfect square:
num=int(input()) 
val = num ** 0.5:
print(val)
if val == int(val):
    print(f"{num} is perfect square
