# %%
#1. Single Inheritance
#with implementation in child class
# when child class don't have constructor,In this case parent class constructor behave like child class constructor
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def details(self):
        return f"My name is {self.name} and I am a {self.age} years old"
#child class
class Student(Person):
    pass

s = Student("moulya",21)
print(s.name)
print(s.details())
# Out:
# moulya
# My name is moulya and I am a 21 years old

# %%
# 1. SINGLE INHERITANCE:
class Person:
    def __init__(self,name,age,gender):
        self.name=name
        self.age=age
        self.gender=gender
    def details(self):
        return f"My name is {self.name} and I am a {self.age} years old and {self.gender}"
#child class
class Student(Person):
    def __init__(self,stdid,name,age):
        self.stdid=stdid
        self.name=name
        self.age=age
        
p=Person("Dinnu",30,"Male")
s = Student(101,"moulya",21)
print(s.name)
print(p.details())
s.gender="female" 
print(s.details())
# Out:
# moulya
# My name is Dinnu and I am a 30 years old and Male
# My name is moulya and I am a 21 years old and female

# %%
#inheritance the parent class constructor in child class by using super()
#super(): this function is user to get the parent class implementation in child clss
class Person:
    def __init__(self,name,age,gender):
        self.name=name
        self.age=age
        self.gender=gender
    def details(self):
        return f"My name is {self.name} and I am a {self.age} years old and {self.gender}"
#child class
class Student(Person):
    def __init__(self,stdid,name,age,gender): 
        self.stdid=stdid
        super().__init__(name,age,gender)

    def percentage(self,marks:list):
        return sum(marks)/len(marks)
        

s = Student(101,"moulya",21,"female")
print(s.name)
print(s.details())

print(s.percentage([90,86,94]))
# Out:
# moulya
# My name is moulya and I am a 21 years old and female
# 90.0

# %%
employee
   company- class attribute
   id, name , salary

teamlead
  id , name , salary , project_name
manager
  id , name , salary , project , no_projects
  -Handling_projects()

# %%
# 2. MULTILEVEL INHERITANCE:

class Employee:
    company = "MOULYA IT SOLUTIONS"
    def __init__(self,id,name,salary):
        self.id=id 
        self.name=name
        self.salary=salary
    def calculate_salary(self,bonous=0):
        return self.salary+bonous

class Teamlead(Employee):
    def __init__(self,id,name,salary,project_name):
        self.project_name=project_name
        super().__init__(id,name,salary)
    def project_status(self,status):
        return f"{self.project_name} project status:{status} % completed"
class Manager(Teamlead):
   def __init__(self,id,name,salary,project_name,no_projects):
       self.no_projects=no_projects
       super().__init__(id,name,salary,project_name)

e=Employee(123,"Moulya",35000)
t=Teamlead(102,"Mouli",40000,"practice Tracking project")
m=Manager(103,"DINNU",60000,"Exam portal project",5)
print(e.name,t.name,m.name)
print(e.calculate_salary())
print(t.calculate_salary(5000))
print(t.project_status(90))
print(m.calculate_salary(10000))
print(m.project_status(80))
# Out:
# Moulya Mouli DINNU
# 35000
# 45000
# practice Tracking project project status:90 % completed
# 70000
# Exam portal project project status:80 % completed

# %%
# 3. MULTIPLE INHERITANCE:
class Father:
    def __init__(self,Father_name):
        self.Father_name=Father_name
    def Working(self):
        return "Father Working as Enginner" 

class Mother:
    def __init__(self,Mother_name):
        self.Mother_name=Mother_name
    def Working(self):
        return "Mother Working as Teacher"

class Child(Father,Mother):
    def __init__(self,name,Father_name,Mother_name):
        self.name=name
        Mother.__init__(self,Mother_name)
        Father.__init__(self,Father_name)
    def Working(self):
        f=Father(self.Father_name)
        m=Mother(self.Mother_name)
        print(f.Working())
        print(m.Working())

c=Child("Moulya","Kumaraswamy","Lalitha")
print(c.Father_name)
print(c.Mother_name)
print(Child.__mro__)#method resolution order
print(c.Working())
# Out:
# Kumaraswamy
# Lalitha
# (<class '__main__.Child'>, <class '__main__.Father'>, <class '__main__.Mother'>, <class 'object'>)
# Father Working as Enginner
# Mother Working as Teacher
# None

# %%
Father
  father_name
  -working
Mother
  mother_name
  -working
Child
  father_name,mother_name
  -working(father,mother)

# %%
# 3. MULTIPLE INHERITANCE:
class Father:
    def __init__(self,Father_name):
        self.Father_name=Father_name
    def Working1(self):
        return "Father Working as Enginner" 

class Mother:
    def __init__(self,Mother_name):
        self.Mother_name=Mother_name
    def Working2(self):
        return "Mother Working as Teacher"

class Child(Father,Mother):
    def __init__(self,name,Father_name,Mother_name):
        self.name=name
        Mother.__init__(self,Mother_name)
        Father.__init__(self,Father_name)
    def Working(self):
        #f=Father(self.Father_name)
        #m=Mother(self.Mother_name)
        print(super().Working1())
        print(super().Working2())

c=Child("Moulya","Kumaraswamy","Lalitha")
print(c.Father_name)
print(c.Mother_name)
print(Child.__mro__)#method resolution order
print(c.Working())
# Out:
# Kumaraswamy
# Lalitha
# (<class '__main__.Child'>, <class '__main__.Father'>, <class '__main__.Mother'>, <class 'object'>)
# Father Working as Enginner
# Mother Working as Teacher
# None
