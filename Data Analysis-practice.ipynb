# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(dir(np))
# Out:
# ['False_', 'ScalarType', 'True_', '_CopyMode', '_NoValue', '__NUMPY_SETUP__', '__all__', '__array_api_version__', '__array_namespace_info__', '__builtins__', '__cached__', '__config__', '__dir__', '__doc__', '__expired_attributes__', '__file__', '__former_attrs__', '__future_scalars__', '__getattr__', '__loader__', '__name__', '__numpy_submodules__', '__package__', '__path__', '__spec__', '__version__', '_array_api_info', '_core', '_distributor_init', '_expired_attrs_2_0', '_globals', '_int_extended_msg', '_mat', '_msg', '_pyinstaller_hooks_dir', '_pytesttester', '_specific_msg', '_type_info', '_typing', '_utils', 'abs', 'absolute', 'acos', 'acosh', 'add', 'all', 'allclose', 'amax', 'amin', 'angle', 'any', 'append', 'apply_along_axis', 'apply_over_axes', 'arange', 'arccos', 'arccosh', 'arcsin', 'arcsinh', 'arctan', 'arctan2', 'arctanh', 'argmax', 'argmin', 'argpartition', 'argsort', 'argwhere', 'around', 'array', 'array2string', 'array_equal', 'array_equiv', 'array_repr', 'array_spli
# ...

# %%
a = np.array([10, 20, 30, 40, 50])
print(a)
# Out:
# [10 20 30 40 50]

# %%
a = np.array([[10, 20, 30],
              [40, 50, 60]])

print(a)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
print(a[0])
print(a[1])
# Out:
# [10 20 30]
# [40 50 60]

# %%
print(a[0, 1])
print(a[1, 2])
# Out:
# 20
# 60

# %%
print(a[0, :])
print(a[:, 1])
# Out:
# [10 20 30]
# [20 50]

# %%
print(a + 10)
print(a * 2)
# Out:
# [[20 30 40]
#  [50 60 70]]
# [[ 20  40  60]
#  [ 80 100 120]]

# %%
print(a.shape)
print(a.size)
# Out:
# (2, 3)
# 6

# %%
print(a.dtype)
# Out:
# int64

# %%
print(a.sum())
# Out:
# 210

# %%
print(a.mean())
# Out:
# 35.0

# %%
print(a.max())
print(a.min())
# Out:
# 60
# 10

# %%
b = np.array([1, 2, 3, 4, 5, 6])

b = b.reshape(2, 3)

print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("Housing.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    str
#  6   guestroom         545 non-null    str
#  7   basement          545 non-null    str
#  8   hotwaterheating   545 non-null    str
#  9   airconditioning   545 non-null    str
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    str
#  12  furnishingstatus  545 non-null    str
# dtypes: int64(6), str(7)
# memory usage: 55.5 KB

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='str')

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.describe(include="object")
# Out:
# C:\Users\moulya_meruva\AppData\Local\Temp\ipykernel_24800\702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# Length: 545, dtype: bool

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.dtypes
# Out:
# price               int64
# area                int64
# bedrooms            int64
# bathrooms           int64
# stories             int64
# mainroad              str
# guestroom             str
# basement              str
# hotwaterheating       str
# airconditioning       str
# parking             int64
# prefarea              str
# furnishingstatus      str
# dtype: object

# %%
df.select_dtypes(include="int64").columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking'], dtype='str')

# %%
df.select_dtypes(include="str").columns
# Out:
# Index(['mainroad', 'guestroom', 'basement', 'hotwaterheating',
#        'airconditioning', 'prefarea', 'furnishingstatus'],
#       dtype='str')

# %%
df.select_dtypes(include="int64").describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
categorical_columns = [
    'mainroad',
    'guestroom',
    'basement',
    'hotwaterheating',
    'airconditioning',
    'prefarea',
    'furnishingstatus'
]

# %%
def transfer(x):
    if x == 'yes':
        return 1
    else:
        return 0
df['mainroad'] = df['mainroad'].apply(transfer)

df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad guestroom  \
# 0    13300000  7420         4          2        3         1        no
# 1    12250000  8960         4          4        4         1        no
# 2    12250000  9960         3          2        2         1        no
# 3    12215000  7500         4          2        2         1        no
# 4    11410000  7420         4          1        2         1       yes
# ..        ...   ...       ...        ...      ...       ...       ...
# 540   1820000  3000         2          1        1         1        no
# 541   1767150  2400         3          1        1         0        no
# 542   1750000  3620         2          1        1         1        no
# 543   1750000  2910         3          1        1         0        no
# 544   1750000  3850         3          1        2         1        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
def transfer(x):
    if x == 'yes':
        return 1
    else:
        return 0
df['guestroom'] = df['guestroom'].apply(transfer)

df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         0          0
# 1    12250000  8960         4          4        4         0          0
# 2    12250000  9960         3          2        2         0          0
# 3    12215000  7500         4          2        2         0          0
# 4    11410000  7420         4          1        2         0          0
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         0          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         0          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         0          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
def transfer(x):
    if x == 'yes':
        return 1
    else:
        return 0
df['basement'] = df['basement'].apply(transfer)

df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         0          0
# 1    12250000  8960         4          4        4         0          0
# 2    12250000  9960         3          2        2         0          0
# 3    12215000  7500         4          2        2         0          0
# 4    11410000  7420         4          1        2         0          0
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         0          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         0          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         0          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
def transfer(x):
    if x == 'yes':
        return 1
    else:
        return 0
df['hotwaterheating'] = df['hotwaterheating'].apply(transfer)

df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         0          0
# 1    12250000  8960         4          4        4         0          0
# 2    12250000  9960         3          2        2         0          0
# 3    12215000  7500         4          2        2         0          0
# 4    11410000  7420         4          1        2         0          0
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         0          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         0          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         0          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
def transfer(x):
    if x == 'yes':
        return 1
    else:
        return 0
df['airconditioning'] = df['airconditioning'].apply(transfer)

df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         0          0
# 1    12250000  8960         4          4        4         0          0
# 2    12250000  9960         3          2        2         0          0
# 3    12215000  7500         4          2        2         0          0
# 4    11410000  7420         4          1        2         0          0
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         0          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         0          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         0          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
def transfer(x):
    if x == 'yes':
        return 1
    else:
        return 0
df['prefarea'] = df['prefarea'].apply(transfer)

df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         0          0
# 1    12250000  8960         4          4        4         0          0
# 2    12250000  9960         3          2        2         0          0
# 3    12215000  7500         4          2        2         0          0
# 4    11410000  7420         4          1        2         0          0
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         0          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         0          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         0          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
# Load dataset
df = pd.read_csv("Housing.csv")

# Function for Yes/No transformation
def transfer(x):
    if x == 'yes':
        return 1
    else:
        return 0

# Mainroad
df['mainroad'] = df['mainroad'].apply(transfer)

# Guestroom
df['guestroom'] = df['guestroom'].apply(transfer)

# Basement
df['basement'] = df['basement'].apply(transfer)

# Hotwaterheating
df['hotwaterheating'] = df['hotwaterheating'].apply(transfer)

# Airconditioning
df['airconditioning'] = df['airconditioning'].apply(transfer)

# Prefarea
df['prefarea'] = df['prefarea'].apply(transfer)

# Display dataframe
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
df['furnishingstatus'].value_counts()
# Out:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64

# %%
def transfer(x):
    if x == 'unfurnished':
        return 0
    elif x == 'semi-furnished':
        return 0.5
    else:
        return 1

df['furnishingstatus'] = df['furnishingstatus'].apply(transfer)

df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
#check datatype of each column
df.dtypes
# Out:
# price                 int64
# area                  int64
# bedrooms              int64
# bathrooms             int64
# stories               int64
# mainroad              int64
# guestroom             int64
# basement              int64
# hotwaterheating       int64
# airconditioning       int64
# parking               int64
# prefarea              int64
# furnishingstatus    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr()
# Out:
#                      price      area  bedrooms  bathrooms   stories  mainroad  \
# price             1.000000  0.535997  0.366494   0.517545  0.420712  0.296898
# area              0.535997  1.000000  0.151858   0.193820  0.083996  0.288874
# bedrooms          0.366494  0.151858  1.000000   0.373930  0.408564 -0.012033
# bathrooms         0.517545  0.193820  0.373930   1.000000  0.326165  0.042398
# stories           0.420712  0.083996  0.408564   0.326165  1.000000  0.121706
# mainroad          0.296898  0.288874 -0.012033   0.042398  0.121706  1.000000
# guestroom         0.255517  0.140297  0.080549   0.126469  0.043538  0.092337
# basement          0.187057  0.047417  0.097312   0.102106 -0.172394  0.044002
# hotwaterheating   0.093073 -0.009229  0.046049   0.067159  0.018847 -0.011781
# airconditioning   0.452954  0.222393  0.160603   0.186915  0.293602  0.105423
# parking           0.384394  0.352980  0.139270   0.177496  0.045547  0.204433
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#          mainroad   guestroom    basement  hotwaterheating  airconditioning  \
# count  545.000000  545.000000  545.000000       545.000000       545.000000
# mean     0.858716    0.177982    0.350459         0.045872         0.315596
# std      0.348635    0.382849    0.477552         0.209399         0.465180
# ...

# %%
df.corr()
# Out:
#                      price      area  bedrooms  bathrooms   stories  mainroad  \
# price             1.000000  0.535997  0.366494   0.517545  0.420712  0.296898
# area              0.535997  1.000000  0.151858   0.193820  0.083996  0.288874
# bedrooms          0.366494  0.151858  1.000000   0.373930  0.408564 -0.012033
# bathrooms         0.517545  0.193820  0.373930   1.000000  0.326165  0.042398
# stories           0.420712  0.083996  0.408564   0.326165  1.000000  0.121706
# mainroad          0.296898  0.288874 -0.012033   0.042398  0.121706  1.000000
# guestroom         0.255517  0.140297  0.080549   0.126469  0.043538  0.092337
# basement          0.187057  0.047417  0.097312   0.102106 -0.172394  0.044002
# hotwaterheating   0.093073 -0.009229  0.046049   0.067159  0.018847 -0.011781
# airconditioning   0.452954  0.222393  0.160603   0.186915  0.293602  0.105423
# parking           0.384394  0.352980  0.139270   0.177496  0.045547  0.204433
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="parking")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="bedrooms")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="bedrooms")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="bathrooms")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="stories")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="mainroad")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="guestroom")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="basement")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="mainroad")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="mainroad", hue="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="guestroom", hue="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="basement", hue="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="hotwaterheating", hue="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.countplot(data=df, x="airconditioning", hue="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.lineplot(data=df, x="mainroad", y="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.lineplot(data=df, x="bedrooms", y="price")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.lineplot(data=df, x="area", y="price")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.lineplot(data=df, x="bathrooms", y="price")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.lineplot(data=df, x="stories", y="price")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.lineplot(data=df, x="parking", y="price")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.lineplot(data=df, x="furnishingstatus", y="price")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.lineplot(data=df, x="hotwaterheating", y="price")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.kdeplot(data=df, x="mainroad", hue="parking")
plt.show()
# Out:
# C:\Users\moulya_meruva\AppData\Local\Temp\ipykernel_24800\2954794413.py:3: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df, x="mainroad", hue="parking")

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.kdeplot(data=df, x="area", hue="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.kdeplot(data=df, x="bedrooms", hue="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.kdeplot(data=df, x="price", hue="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.kdeplot(data=df, x="bathrooms", hue="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.scatterplot(data=df, x="mainroad", y="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.scatterplot(data=df, x="area", y="price")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.scatterplot(data=df, x="bedrooms", y="price")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.scatterplot(data=df, x="bathrooms", y="price")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.scatterplot(data=df, x="stories", y="price")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.scatterplot(data=df, x="mainroad", y="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.scatterplot(data=df, x="mainroad", y="price", hue="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.scatterplot(data=df, x="area", y="price", hue="parking")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.scatterplot(data=df, x="bedrooms", y="price", hue="parking")
plt.show()

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='str')

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.boxplot(data=df[['bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'furnishingstatus']])

plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.boxplot(data=df)
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.histplot(data=df, x="price", kde=True)
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.histplot(data=df, x="area", kde=True)
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.histplot(data=df, x="bedrooms", kde=True)
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.boxplot(data=df[['bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'furnishingstatus']])

plt.xticks(rotation=45)

plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.boxplot(data=df, x="price")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.boxplot(data=df, x="area")
plt.show()

# %%
# data visualization
plt.figure(figsize=(8,8))
sns.boxplot(data=df, x="bedrooms")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(data=df, x="price")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data=df.corr(numeric_only=True), annot=True)
plt.show()

# %%
X = df.drop('price', axis=1)
y = df['price']

# %%
print(X.shape)
print(y.shape)
# Out:
# (545, 12)
# (545,)
