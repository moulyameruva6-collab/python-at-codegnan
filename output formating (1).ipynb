# %% [markdown]
# #
# name="moulya"
# age=20
# # my name is moulya and i am a 20 years old
# print("my name"+name+"and i am a"+str(age)+"year old")

# %%
#output formating
#
name="moulya"
age=21
marks=[85,86,92,84,97,87]
# my name is moulya and im a 21 year old
print("my name"+name+"and i am a"+ str(age) +"year old")
# Out:
# my namemoulyaand i am a21year old

# %%
#output formating
#1 out style formating(using comma)
name="moulya"
age=21
marks=[85,86,92,84,97,87]
# my name is moulya and im a 21 year old
print("my name" , name ,"and i am " , age ," year old")
# Out:
# my name moulya and i am  21  year old

# %%
#1.Acess specifiers:
#integer-%d
#float-%f
#string-%s
name="moulya"
age=21
marks=[85,86,92,84,97,87]
# my name is moulya and im a 21 year old
print("my name %s name and i am a %d year old"%(name,age))
# Out:
# my name moulya name and i am a 21 year old

# %%
### output formating:
#3.dot format
name="moulya"
age=21
marks=[85,86,92,84,97,87]
# my name is moulya and im a 21 year old
print("my name {} name and i am a {} year old".format(name,age))
print("my name {} name and i am a {} year old".format(age,name))
# Out:
# my name moulya name and i am a 21 year old
# my name 21 name and i am a moulya year old

# %%
### output formating:
#4.f- format
name="moulya"
age=21
marks=[85,86,92,84,97,87]
# my name is moulya and im a 21 year old
percentage=98.2548
print(f"my name{name}.i am a{age} year old and my percentage is{percentage}")
print(f"my name{name}.i am a{age} year old and my percentage is{percentage:.2f}")
# Out:
# my namemoulya.i am a21 year old and my percentage is98.2548
# my namemoulya.i am a21 year old and my percentage is98.25
