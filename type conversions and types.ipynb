# %%
n=input()
print(type(n))
print(n)
# Out:
#  moulya
# <class 'str'>
# moulya

# %%
#reading integer from user
#integer to float,string,bool
n=int(input())
print(type(n),n)
# Out:
#  10
# <class 'int'> 10

# %%
#reading integer from user
#integer to float,string,bool
n=int(input())
print(type(n),n)
print(float(n))
print(str(n))
print(bool(n))
# Out:
#  23
# <class 'int'> 23
# 23.0
# 23
# True

# %%
#reading float value from user
#float to int,string bool
val=float(input())
print(type(val),val)
print(str(val))
print(bool(val))
print(int(val))
# Out:
#  12
# <class 'float'> 12.0
# 12.0
# True
# 12

# %%
#reading float value from user
#float to int,string bool
val=float(input())
print(type(val),val)
print(str(val)[:3])
print(bool(val))
print(int(val))
print(str(val))
# Out:
#  123.432
# <class 'float'> 123.432
# 123
# True
# 123
# 123.432

# %%
#reading complex value:
real=int(input())
img=int(input())
c=complex(real,img)
print(type(c),c)
# Out:
#  13
#  12
# <class 'complex'> (13+12j)

# %%
#reading float value from user
#float to int,string bool
val=float(input())
print(type(val),val)
print(str(val))
print(bool(val))
print(int(val))
# Out:
#  123
# <class 'int'> 13
# 123
# 123.0

# %%
#reading float value from user
#float to int,string bool
val=float(input())
print(type(val),val)
print(str(val))
print(bool(val))
print(int(val))
# Out:
#  moulya
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 3
#       1 #reading float value from user
#       2 #float to int,string bool
# ----> 3 val=float(input())
#       4 print(type(val),val)
#       5 print(str(val))
#       6 print(bool(val))
#
# ValueError: could not convert string to float: 'moulya'

# %%
#reading string value from user:
s=input()
print(type(s),s)
print(int(s))
print(float(s))
print(tuple(s))
print(set(s))
# Out:
#  12
# <class 'str'> 12
# 12
# 12.0
# ('1', '2')
# {'2', '1'}

# %%
#reading string value from user:
s=input()#123
print(type(s),s)
print(int(s))
print(float(s))#it returns list of chaaracters
print(tuple(s))#it returns tuple of characters
print(set(s))#it returns set of characters
# Out:
#  123
# <class 'str'> 123
# 123
# 123.0
# ('1', '2', '3')
# {'2', '3', '1'}

# %%
#reading string value from user:
s=input()#123
print(type(s),s)
print(int(s))
print(float(s))#it returns list of chaaracters
print(tuple(s))#it returns tuple of characters
print(set(s))#it returns set of characters
# Out:
#  hello
# <class 'str'> hello
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 4
#       1 #reading string value from user:
#       2 s=input()#123
#       3 print(type(s),s)
# ----> 4 print(int(s))
#       5 print(float(s))#it returns list of chaaracters
#       6 print(tuple(s))#it returns tuple of characters
#       7 print(set(s))#it returns set of characters
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
#reading string value from user:
s=input()#"hello"
print(type(s),s)
#print(int(s))
l=list(s)
print(l[-4:5])#it returns list of chaaracters
print(tuple(s))#it returns tuple of characters
print(set(s))#it returns set of characters
# Out:
#  moulya
# <class 'str'> moulya
# ['u', 'l', 'y']
# ('m', 'o', 'u', 'l', 'y', 'a')
# {'u', 'o', 'a', 'y', 'm', 'l'}

# %%
#reading string value from user:
s=input()#"hello"
print(type(s),s)
#print(int(s))
l=list(s)
print(l[-4:5])#it returns list of chaaracters
print(tuple(s))#it returns tuple of characters
print(set(s))#it returns set of characters
# Out:
#  hello
# <class 'str'> hello
# ['e', 'l', 'l', 'o']
# ('h', 'e', 'l', 'l', 'o')
# {'h', 'o', 'l', 'e'}

# %%
#reading list of integers:
s=input()
print(s)
# Out:
#  1 2 3
# 1 2 3

# %%
#reading list of integers:
s=map(int,input().split())
print(s)
# Out:
#  1 2 3
# ...

# %%
#reading list of integers:
s=list(map(int,input().split()))
print(s)
# Out:
#  1 2 3
# [1, 2, 3]

# %%
#list to tuple,set,string
l=list(map(int,input().split()))
print(l)
print(tuple(l))
print(set(l))
s=str(l)
print(s[0])
print(s)
# Out:
#  1 2 3
# [1, 2, 3]
# (1, 2, 3)
# {1, 2, 3}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 6
#       2 l=list(map(int,input().split()))
#       3 print(l)
#       4 print(tuple(l))
#       5 print(set(l))
# ----> 6 s=str(l)
#       7 print(s[0])
#       8 print(s)
#
# TypeError: 'int' object is not callable

# %%
#list to tuple,set,string
l=list(map(int,input().split()))
print(l)
print(tuple(l))
print(set(l))
s=str(l)
print(s[0])
print(s)

# %%
#read list of strings:
l=list(map(str,input().split()))
print(l)
# Out:
#  hii hello him
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 2
#       1 #read list of strings:
# ----> 2 l=list(map(str,input().split()))
#       3 print(l)
#
# TypeError: 'int' object is not callable

# %%
#read tuple of integers:
t= tuple(map(int,input().split()))
print(list(t))
print(set(t))
print(str(t))
# Out:
#  1 12 123 123
# [1, 12, 123, 123]
# {1, 123, 12}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 5
#       1 #read tuple of integers:
#       2 t= tuple(map(int,input().split()))
#       3 print(list(t))
#       4 print(set(t))
# ----> 5 print(str(t))
#
# TypeError: 'int' object is not callable

# %%
#read set of integers:
s= set(map(int,input().split()))
print(list(s))
print(tuple(s))
print(str(s))
# Out:
#  1 12 123 12
# [1, 123, 12]
# (1, 123, 12)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 5
#       1 #read set of integers:
#       2 s= set(map(int,input().split()))
#       3 print(list(s))
#       4 print(tuple(s))
# ----> 5 print(str(s))
#
# TypeError: 'int' object is not callable

# %%
#eval(string):it evalutes the string type expression
print("3+5")
print(3+5)
print(eval("3+5"))
# Out:
# 3+5
# 8
# 8

# %%
#read tuple of integers:
t= tuple(map(int,input().split()))
print(list(t))
print(set(t))
print(str(t))
# Out:
#  1
# <class 'int'> 1

# %%
n=eval(input())
print(type(n),n)
# Out:
#  1
# <class 'int'> 1

# %%
n=eval(input())
print(type(n),n)
# Out:
#  "moulya"
# <class 'str'> moulya

# %%
n=eval(input())
print(type(n),n)
# Out:
#  {"name":"moulya","age":20}
# <class 'dict'> {'name': 'moulya', 'age': 20}

# %%
n=eval(input())
print(type(n),n)
# Out:
#  [12,32,42]
# <class 'list'> [12, 32, 42]

# %%
n=eval(input())
print(type(n),n)
# Out:
#  ["moulya",13,"python"]
# <class 'list'> ['moulya', 13, 'python']
