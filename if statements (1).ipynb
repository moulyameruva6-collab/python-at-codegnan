# %%
num=int(input())
if num % 2 ==0:
    print("even")
if num % 2 ==1:
    print("odd")
# Out:
#  42
# even

# %%
num=int(input())
if num % 2 ==0:
    print(f"{num} is even")
if num % 2 ==1:
    print(f"{num} is odd")
# Out:
#  13
# 13 is odd

# %%
num=int(input())
if num % 3 ==0:
    print("Fizz")
if num % 5 ==0:   
    print("Buzz")
else:
    print("Number")
# Out:
#  23
# Number

# %%
num=int(input())
if num % 3 ==0:
    print("Fizz")
if num % 5 ==0:   
    print("Buzz")
else:
    print("Number")
# Out:
#  30
# Fizz

# %%
num=int(input())
if num % 3 ==0:
    print("Fizz")
if num % 5 ==0:   
    print("Buzz")
else:
    print("Number")
# Out:
#  55
# Buzz

# %%
num=int(input())
if num % 3 ==0:
    print("Fizz")
if num % 5 ==0:   
    print("Buzz")
else:
    print(num)
# Out:
#  11
# 11
